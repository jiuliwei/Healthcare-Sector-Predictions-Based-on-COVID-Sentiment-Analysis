# %%
import pandas as pd

# %% [markdown]
# # Chunk

# %%
data = pd.read_csv("/Users/joye/学习/PA/project/tweetid_userid_keyword_sentiments_emotions_United States.csv")
data.describe()
data.shape
index = 0
for i in range(68):
    fileName = "chunk"+str(i)+".csv"
    data[:][index:index+1000000].to_csv(fileName,index=False)
    index += 1000000
data[:][index:].to_csv(fileName,index=False)

# %%
data = pd.read_csv("/Users/joye/学习/PA/project/tweetid_userid_keyword_sentiments_emotions_United States.csv")
# Out:
#            tweet_ID       user_id  valence_intensity  fear_intensity  \
# count  6.893509e+07  6.893509e+07       6.893509e+07    6.893509e+07
# mean   1.349877e+18  3.149627e+17       4.546974e-01    4.470237e-01
# std    8.239929e+16  4.961657e+17       9.658794e-02    9.584690e-02
# min    1.221958e+18  1.300000e+01      -4.700000e-02   -5.300000e-02
# 25%    1.279554e+18  6.510951e+07       3.880000e-01    3.800000e-01
# 50%    1.334081e+18  6.226798e+08       4.550000e-01    4.450000e-01
# 75%    1.421984e+18  8.160470e+17       5.200000e-01    5.120000e-01
# max    1.532331e+18  1.532236e+18       1.005000e+00    1.092000e+00
#
#        anger_intensity  happiness_intensity  sadness_intensity     sentiment
# count     6.893509e+07         6.893509e+07       6.893509e+07  6.893509e+07
# mean      4.462618e-01         2.945840e-01       4.183409e-01 -3.959883e-01
# std       9.055730e-02         9.584745e-02       8.157344e-02  9.346144e-01
# min      -7.000000e-03        -1.000000e-01       4.100000e-02 -2.000000e+00
# 25%       3.820000e-01         2.270000e-01       3.600000e-01 -1.000000e+00
# 50%       4.410000e-01         2.900000e-01       4.120000e-01 -1.000000e+00
# 75%       5.040000e-01         3.560000e-01       4.700000e-01  0.000000e+00
# max       1.059000e+00         9.840000e-01       9.860000e-01  2.000000e+00

# %%
data
# Out:
#                      tweet_ID              user_id keywords  \
# 0         1221958334661779458             18527874    wuhan
# 1         1221959351461720064             35527998    wuhan
# 2         1221959956951224320            415915436    wuhan
# 3         1221961233026281472             22586384    wuhan
# 4         1221961678058926080           2399087653    wuhan
# ...                       ...                  ...      ...
# 68935084  1532331150697431040            213423594    covid
# 68935085  1532331161011245056   884826266481897473    covid
# 68935086  1532331169785819143  1352804365971632129    covid
# 68935087  1532331184000311298            525813230    covid
# 68935088  1532331190996418561  1081228923848007680    covid
#
#               tweet_timestamp  valence_intensity  fear_intensity  \
# 0         2020-01-28 00:49:04              0.513           0.550
# 1         2020-01-28 00:53:06              0.526           0.387
# 2         2020-01-28 00:55:31              0.578           0.328
# 3         2020-01-28 01:00:35              0.497           0.464
# 4         2020-01-28 01:02:21              0.448           0.449
# ...                       ...                ...             ...
# 68935084  2022-06-02 11:59:50              0.502           0.430
# 68935085  2022-06-02 11:59:52              0.634           0.364
# 68935086  2022-06-02 11:59:54              0.435           0.384
# 68935087  2022-06-02 11:59:58              0.501           0.526
# 68935088  2022-06-02 11:59:59              0.538           0.424
#
#           anger_intensity  happiness_intensity  sadness_intensity  sentiment  \
# 0                   0.358                0.364              0.344          0
# 1                   0.421                0.364              0.368          1
# 2                   0.280                0.440              0.383          1
# 3                   0.431                0.339              0.388          0
# 4                   0.425                0.291              0.474         -1
# ...                   ...                  ...                ...        ...
# 68935084            0.483                0.402              0.381          0
# 68935085            0.412                0.429              0.330          1
# 68935086            0.390                0.204              0.397         -1
# 68935087            0.411                0.256              0.369          0
# 68935088            0.370                0.360              0.386          1
#
#          emotion
# 0            NaN
# 1              H
# 2              H
# 3            NaN
# 4              S
# ...          ...
# 68935084     NaN
# 68935085       H
# 68935086       S
# 68935087     NaN
# 68935088       H
#
# [68935089 rows x 11 columns]

# %% [markdown]
# # Create New Data File

# %%
for index in range(69):
    #data = pd.read_csv("/Users/joye/学习/PA/project/tweetid_userid_keyword_sentiments_emotions_United States.csv")
    data = pd.read_csv("/Users/joye/学习/PA/project/chunk"+str(index)+".csv")
    data = data.drop('tweet_ID', axis=1)
    data = data.drop('user_id', axis=1)
    data = data.drop('keywords', axis=1)
    data.loc[1000000] = data.loc[0]
    df = pd.DataFrame(columns=('tweet_timestamp','count','sent_-2','sent_-1','sent_0','sent_1','sent_2','emo_A',
                              'emo_F','emo_H','emo_S','valence_intensity','fear_intensity','anger_intensity',
                              'happiness_intensity','sadness_intensity'))
    count = 0
    date = data['tweet_timestamp'][0].split(' ')[0]
    row = {'tweet_timestamp':date,'count':0,'sent_-2':0,'sent_-1':0,'sent_0':0,'sent_1':0,'sent_2':0,'emo_A':0,
                              'emo_F':0,'emo_H':0,'emo_S':0,'valence_intensity':0,'fear_intensity':0,'anger_intensity':0,
                              'happiness_intensity':0,'sadness_intensity':0}
    total = 0

    n = 0
    for i in range(len(data)):
        if data['tweet_timestamp'][i].split(' ')[0] != date :
            print(date+":"+str(count))
            row['count'] = count
            row['valence_intensity'] /= count
            row['fear_intensity'] /= count
            row['anger_intensity'] /= count
            row['happiness_intensity'] /= count
            row['sadness_intensity'] /= count
            df.loc[n]=row
            n+=1
            total+=count
            date = data['tweet_timestamp'][i].split(' ')[0]
            count = 0
            row = {'tweet_timestamp':date,'count':0,'sent_-2':0,'sent_-1':0,'sent_0':0,'sent_1':0,'sent_2':0,'emo_A':0,
                              'emo_F':0,'emo_H':0,'emo_S':0,'valence_intensity':0,'fear_intensity':0,'anger_intensity':0,
                              'happiness_intensity':0,'sadness_intensity':0}
        count+=1;
        row['sent_'+str(data['sentiment'][i])] += 1
        if data['emotion'][i]=='A' or data['emotion'][i]=='F'or data['emotion'][i]=='H'or data['emotion'][i]=='S':
            row['emo_'+data['emotion'][i]]+=1
        row['valence_intensity'] += data['valence_intensity'][i]
        row['fear_intensity'] += data['fear_intensity'][i]
        row['anger_intensity'] += data['anger_intensity'][i]
        row['happiness_intensity'] += data['happiness_intensity'][i]
        row['sadness_intensity'] += data['sadness_intensity'][i]

    print(date+":"+str(count))
    total+=count
    print("total: "+str(total))
    df.to_csv('output'+str(index)+'.csv',index=False)

# %%
df = pd.read_csv("output0.csv")

for i in range(1,69):
    print(i)
    data = pd.read_csv("output"+str(i)+".csv")
    k = len(df)-1
    if df['tweet_timestamp'][k] == data['tweet_timestamp'][0]:
        df['sent_-2'][k] += data['sent_-2'][0]
        df['sent_-1'][k] += data['sent_-1'][0]
        df['sent_0'][k] += data['sent_0'][0]
        df['sent_1'][k] += data['sent_1'][0]
        df['sent_2'][k] += data['sent_2'][0]
        df['emo_A'][k] += data['emo_A'][0]
        df['emo_F'][k] += data['emo_F'][0]
        df['emo_H'][k] += data['emo_H'][0]
        df['emo_S'][k] += data['emo_S'][0]
        count = df['count'][k] + data['count'][0]
        df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
                                          data['valence_intensity'][0]*data['count'][0])/count
        df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
                                          data['fear_intensity'][0]*data['count'][0])/count
        df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
                                          data['anger_intensity'][0]*data['count'][0])/count
        df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
                                          data['happiness_intensity'][0]*data['count'][0])/count
        df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
                                          data['sadness_intensity'][0]*data['count'][0])/count
        df['count'][k] = count
        data=data.drop(0, axis=0)
    df = pd.concat([df,data],axis = 0)
    df = df.reset_index(drop=True)
# Out:
# 1
# 2
# 3
# 4
# 5
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# 66
# 67
# 68
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][k] += data['sent_-2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][k] += data['sent_-1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][k] += data['sent_0'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][k] += data['sent_1'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][k] += data['sent_2'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][k] += data['emo_A'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][k] += data['emo_F'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][k] += data['emo_H'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][k] += data['emo_S'][0]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['valence_intensity'][k] = (df['valence_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fear_intensity'][k] = (df['fear_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anger_intensity'][k] = (df['anger_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['happiness_intensity'][k] = (df['happiness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sadness_intensity'][k] = (df['sadness_intensity'][k]*df['count'][k]+
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2650954371.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count'][k] = count

# %%
df.to_csv('output.csv',index=False)

# %% [markdown]
# # Remove Weekends

# %%
df = pd.read_csv("/Users/joye/学习/PA/project/output.csv")

# %%
week = 2
i = 0
l = len(df)
while i<l:
    if week == 5:
        row = df.drop('tweet_timestamp', axis = 1).iloc[i:i+3].mean()
        #print("average "+df['tweet_timestamp'][i]+df.iloc[i+1]['tweet_timestamp']+df['tweet_timestamp'][i+2])
        row['tweet_timestamp'] = df['tweet_timestamp'][i]
        df.loc[i] = row
    week = week%7 +1
    i+=1

# %%
week =2
for i in range(len(df)):
    if week == 6 or week ==7:
        df = df.drop([i],axis = 0)
    week = week%7+1

# %%
df.to_csv('output_without_weekend.csv',index=False)

# %% [markdown]
# # Change to Percentage

# %%
df = pd.read_csv("/Users/joye/学习/PA/project/output_without_weekend.csv")
df
# Out:
#     tweet_timestamp         count  sent_-2       sent_-1       sent_0  \
# 0        2020-01-28   9327.000000    421.0   6131.000000  1333.000000
# 1        2020-01-29  14628.000000    780.0   9195.000000  2325.000000
# 2        2020-01-30  15063.000000    736.0   9647.000000  2162.000000
# 3        2020-01-31  11608.666667    516.0   7392.333333  1702.666667
# 4        2020-02-03   8758.000000    398.0   5403.000000  1373.000000
# ..              ...           ...      ...           ...          ...
# 608      2022-05-27  21483.000000   1738.0  12138.666667  2831.666667
# 609      2022-05-30  20050.000000   1625.0  11247.000000  2787.000000
# 610      2022-05-31  26312.000000   1959.0  14878.000000  3786.000000
# 611      2022-06-01  25473.000000   2013.0  14136.000000  3430.000000
# 612      2022-06-02   8058.000000    710.0   4686.000000  1072.000000
#
#           sent_1      sent_2        emo_A        emo_F        emo_H  \
# 0    1409.000000   33.000000  1746.000000  4548.000000  1442.000000
# 1    2286.000000   42.000000  2838.000000  6755.000000  2328.000000
# 2    2478.000000   40.000000  2946.000000  7072.000000  2518.000000
# 3    1959.000000   38.666667  2260.333333  5359.666667  1997.666667
# 4    1542.000000   42.000000  1350.000000  4238.000000  1584.000000
# ..           ...         ...          ...          ...          ...
# 608  4570.333333  204.333333  6658.000000  5807.666667  4774.666667
# 609  4232.000000  159.000000  6219.000000  5325.000000  4391.000000
# 610  5464.000000  225.000000  7904.000000  7258.000000  5689.000000
# 611  5594.000000  300.000000  7832.000000  6759.000000  5894.000000
# 612  1512.000000   78.000000  2618.000000  2251.000000  1590.000000
#
#            emo_S  valence_intensity  fear_intensity  anger_intensity  \
# 0     258.000000           0.438082        0.495200         0.445539
# 1     382.000000           0.437354        0.494122         0.448490
# 2     365.000000           0.438925        0.493577         0.446161
# 3     288.333333           0.441726        0.488082         0.444245
# 4     213.000000           0.444986        0.494471         0.437506
# ..           ...                ...             ...              ...
# 608  1411.000000           0.441824        0.465745         0.465945
# 609  1328.000000           0.441279        0.463497         0.463838
# 610  1675.000000           0.443052        0.465012         0.463310
# 611  1558.000000           0.444818        0.464235         0.463651
# 612   527.000000           0.435603        0.469856         0.472064
#
#      happiness_intensity  sadness_intensity
# 0               0.287662           0.424826
# 1               0.290009           0.428533
# 2               0.289947           0.426665
# 3               0.290290           0.423104
# 4               0.293145           0.422798
# ..                   ...                ...
# 608             0.283419           0.435830
# 609             0.281493           0.435154
# 610             0.281286           0.434718
# 611             0.283742           0.434242
# 612             0.276964           0.440111
#
# [613 rows x 16 columns]

# %%
for i in range(len(df)):
    df['sent_-2'][i] =  df['sent_-2'][i]/df['count'][i]
    df['sent_-1'][i] =  df['sent_-1'][i]/df['count'][i]
    df['sent_0'][i] =  df['sent_0'][i]/df['count'][i]
    df['sent_1'][i] =  df['sent_1'][i]/df['count'][i]
    df['sent_2'][i] =  df['sent_2'][i]/df['count'][i]
    df['emo_A'][i] =  df['emo_A'][i]/df['count'][i]
    df['emo_F'][i] =  df['emo_F'][i]/df['count'][i]
    df['emo_H'][i] =  df['emo_H'][i]/df['count'][i]
    df['emo_S'][i] =  df['emo_S'][i]/df['count'][i]

# %%
df.to_csv('output_percent.csv',index=False)

# %%
df = pd.read_csv("/Users/joye/学习/PA/project/output_percent.csv")
SP = pd.read_csv("/Users/joye/学习/PA/project/SPHC.csv")
df
# Out:
#     tweet_timestamp         count   sent_-2   sent_-1    sent_0    sent_1  \
# 0        2020-01-28   9327.000000  0.045138  0.657339  0.142918  0.151067
# 1        2020-01-29  14628.000000  0.053322  0.628589  0.158942  0.156276
# 2        2020-01-30  15063.000000  0.048861  0.640443  0.143531  0.164509
# 3        2020-01-31  11608.666667  0.044450  0.636794  0.146672  0.168753
# 4        2020-02-03   8758.000000  0.045444  0.616922  0.156771  0.176068
# ..              ...           ...       ...       ...       ...       ...
# 608      2022-05-27  21483.000000  0.080901  0.565036  0.131810  0.212742
# 609      2022-05-30  20050.000000  0.081047  0.560948  0.139002  0.211072
# 610      2022-05-31  26312.000000  0.074453  0.565445  0.143889  0.207662
# 611      2022-06-01  25473.000000  0.079025  0.554941  0.134652  0.219605
# 612      2022-06-02   8058.000000  0.088111  0.581534  0.133035  0.187640
#
#        sent_2     emo_A     emo_F     emo_H     emo_S  valence_intensity  \
# 0    0.003538  0.187198  0.487617  0.154605  0.027662           0.438082
# 1    0.002871  0.194011  0.461786  0.159147  0.026114           0.437354
# 2    0.002656  0.195579  0.469495  0.167165  0.024232           0.438925
# 3    0.003331  0.194711  0.461695  0.172084  0.024838           0.441726
# 4    0.004796  0.154145  0.483900  0.180863  0.024321           0.444986
# ..        ...       ...       ...       ...       ...                ...
# 608  0.009511  0.309919  0.270338  0.222253  0.065680           0.441824
# 609  0.007930  0.310175  0.265586  0.219002  0.066234           0.441279
# 610  0.008551  0.300395  0.275844  0.216213  0.063659           0.443052
# 611  0.011777  0.307463  0.265340  0.231382  0.061163           0.444818
# 612  0.009680  0.324895  0.279350  0.197319  0.065401           0.435603
#
#      fear_intensity  anger_intensity  happiness_intensity  sadness_intensity
# 0          0.495200         0.445539             0.287662           0.424826
# 1          0.494122         0.448490             0.290009           0.428533
# 2          0.493577         0.446161             0.289947           0.426665
# 3          0.488082         0.444245             0.290290           0.423104
# 4          0.494471         0.437506             0.293145           0.422798
# ..              ...              ...                  ...                ...
# 608        0.465745         0.465945             0.283419           0.435830
# 609        0.463497         0.463838             0.281493           0.435154
# 610        0.465012         0.463310             0.281286           0.434718
# 611        0.464235         0.463651             0.283742           0.434242
# 612        0.469856         0.472064             0.276964           0.440111
#
# [613 rows x 16 columns]

# %%
df.describe()
# Out:
#                count     sent_-2     sent_-1      sent_0      sent_1  \
# count     613.000000  613.000000  613.000000  613.000000  613.000000
# mean    84072.401849    0.055994    0.548024    0.149557    0.238436
# std     46930.811885    0.017082    0.044406    0.014725    0.044534
# min       478.000000    0.025732    0.409955    0.110247    0.151067
# 25%     48868.333333    0.041466    0.515830    0.137530    0.204152
# 50%     77637.000000    0.052068    0.554610    0.147885    0.231823
# 75%    113160.000000    0.071506    0.578851    0.163094    0.273153
# max    285313.000000    0.107431    0.662092    0.192853    0.382806
#
#            sent_2       emo_A       emo_F       emo_H       emo_S  \
# count  613.000000  613.000000  613.000000  613.000000  613.000000
# mean     0.007988    0.283494    0.266223    0.246424    0.054301
# std      0.003043    0.039797    0.051932    0.046735    0.010785
# min      0.002311    0.094572    0.166717    0.154219    0.021953
# 25%      0.006029    0.255877    0.236873    0.211094    0.048434
# 50%      0.007431    0.291459    0.260911    0.239763    0.054965
# 75%      0.009511    0.311368    0.283857    0.282140    0.060838
# max      0.030096    0.386042    0.546001    0.396267    0.089591
#
#        valence_intensity  fear_intensity  anger_intensity  \
# count         613.000000      613.000000       613.000000
# mean            0.453123        0.452165         0.448057
# std             0.013112        0.016592         0.013504
# min             0.424899        0.405050         0.418197
# 25%             0.441601        0.436276         0.436800
# 50%             0.453508        0.451990         0.446358
# 75%             0.463980        0.465441         0.460304
# max             0.491755        0.511676         0.477752
#
#        happiness_intensity  sadness_intensity
# count           613.000000         613.000000
# mean              0.290880           0.420496
# std               0.015201           0.011318
# min               0.254472           0.382460
# 25%               0.276964           0.410914
# 50%               0.291354           0.418076
# 75%               0.305330           0.431111
# max               0.330358           0.450169

# %%
SP = SP.drop('Unnamed: 0', axis = 1)

# %%
SP['Date'][0]
# Out:
# '2020-01-28'

# %%
SP['Date'][0] == df['tweet_timestamp'][0]
# Out:
# True

# %%
df[['Date','High']]
# Out:
#            Date         High
# 0    2020-01-28  1194.689941
# 1    2020-01-29  1195.069946
# 2    2020-01-30  1179.380005
# 3    2020-01-31  1173.199951
# 4    2020-02-03  1172.630005
# ..          ...          ...
# 588  2022-05-26  1538.979980
# 589  2022-05-27  1559.339966
# 590  2022-05-31  1559.339966
# 591  2022-06-01  1543.839966
# 592  2022-06-02  1528.339966
#
# [593 rows x 2 columns]

# %%
df0 = pd.merge(df, SP, left_on='tweet_timestamp',right_on='Date',how='right')

# %%
df0 = df0.drop('Date', axis = 1)

# %%
df0.to_csv('output_concat.csv',index=False)

# %%
df0
# Out:
#     tweet_timestamp         count   sent_-2   sent_-1    sent_0    sent_1  \
# 0        2020-01-28   9327.000000  0.045138  0.657339  0.142918  0.151067
# 1        2020-01-29  14628.000000  0.053322  0.628589  0.158942  0.156276
# 2        2020-01-30  15063.000000  0.048861  0.640443  0.143531  0.164509
# 3        2020-01-31  11608.666667  0.044450  0.636794  0.146672  0.168753
# 4        2020-02-03   8758.000000  0.045444  0.616922  0.156771  0.176068
# ..              ...           ...       ...       ...       ...       ...
# 588      2022-05-26  25173.000000  0.087792  0.570015  0.128789  0.203551
# 589      2022-05-27  21483.000000  0.080901  0.565036  0.131810  0.212742
# 590      2022-05-31  26312.000000  0.074453  0.565445  0.143889  0.207662
# 591      2022-06-01  25473.000000  0.079025  0.554941  0.134652  0.219605
# 592      2022-06-02   8058.000000  0.088111  0.581534  0.133035  0.187640
#
#        sent_2     emo_A     emo_F     emo_H  ...     Volume       Diff  \
# 0    0.003538  0.187198  0.487617  0.154605  ...  202157900  10.339966
# 1    0.002871  0.194011  0.461786  0.159147  ...  166189700   8.630005
# 2    0.002656  0.195579  0.469495  0.167165  ...  199618700  12.040039
# 3    0.003331  0.194711  0.461695  0.172084  ...  228459400  22.829956
# 4    0.004796  0.154145  0.483900  0.180863  ...  207902400  11.520020
# ..        ...       ...       ...       ...  ...        ...        ...
# 588  0.009852  0.302944  0.296031  0.213403  ...  178529300  12.719971
# 589  0.009511  0.309919  0.270338  0.222253  ...  185013000  29.770020
# 590  0.008551  0.300395  0.275844  0.216213  ...  362578700  33.380005
# 591  0.011777  0.307463  0.265340  0.231382  ...  159014200  39.599976
# 592  0.009680  0.324895  0.279350  0.197319  ...  169116300  37.199951
#
#      DiffChange    Return   Return5  MA1030 MA30100  Break30     Vol20  Label
# 0           1.0  0.477113 -2.326380     1.0     1.0      0.0  0.617034     -1
# 1          -1.0 -0.279020 -2.713914     1.0     1.0      0.0  0.602541     -1
# 2           1.0 -0.775370 -2.987806     1.0     1.0      0.0  0.621944     -1
# 3           1.0 -1.985833 -3.292691     1.0     1.0     -1.0  0.748871      1
# 4           1.0  0.925513 -1.652574    -1.0     1.0      0.0  0.765988      1
# ..          ...       ...       ...     ...     ...      ...       ...    ...
# 588        -1.0  0.415281  2.741086    -1.0    -1.0      0.0  1.343798      1
# 589        -1.0  1.717533  3.205348    -1.0    -1.0      0.0  1.277321     -1
# 590         1.0 -1.373653  0.975666    -1.0    -1.0      0.0  1.308182     -1
# 591         1.0 -1.423352 -0.714495    -1.0    -1.0      0.0  1.348318      1
# 592         1.0  0.778344  0.075977     1.0    -1.0      0.0  1.266602     -1
#
# [593 rows x 29 columns]

# %% [markdown]
# # Other Method

# %%
for i in range(len(data)):
    data['tweet_timestamp'][i] =  data['tweet_timestamp'][i].split(' ')[0];
# Out:
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/2892040340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['tweet_timestamp'][i] =  data['tweet_timestamp'][i].split(' ')[0];

# %%
df = pd.DataFrame(data.groupby(['tweet_timestamp']).size(), columns=['count'])

# %%
sent_count = data.groupby(['tweet_timestamp','sentiment']).size()
df['sent_-2'] = ''
df['sent_-1'] = ''
df['sent_0'] = ''
df['sent_1'] = ''
df['sent_2'] = ''
for i in range(len(df)):
    df['sent_-2'][i] = sent_count[i*5]
    df['sent_-1'][i] = sent_count[i*5+1]
    df['sent_0'][i] = sent_count[i*5+2]
    df['sent_1'][i] = sent_count[i*5+3]
    df['sent_2'][i] = sent_count[i*5+4]

emo_count = data.groupby(['tweet_timestamp','emotion']).size()
df['emo_A'] = ''
df['emo_F'] = ''
df['emo_H'] = ''
df['emo_S'] = ''
for i in range(len(df)):
    df['emo_A'][i] = emo_count[i*4]
    df['emo_F'][i] = emo_count[i*4+1]
    df['emo_H'][i] = emo_count[i*4+2]
    df['emo_S'][i] = emo_count[i*4+3]

df['valence_intensity'] = data.groupby(['tweet_timestamp'])['valence_intensity'].mean()
df['fear_intensity'] = data.groupby(['tweet_timestamp'])['fear_intensity'].mean()
df['anger_intensity'] = data.groupby(['tweet_timestamp'])['anger_intensity'].mean()
df['happiness_intensity'] = data.groupby(['tweet_timestamp'])['happiness_intensity'].mean()
df['sadness_intensity'] = data.groupby(['tweet_timestamp'])['sadness_intensity'].mean()
# Out:
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-2'][i] = sent_count[i*5]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_-1'][i] = sent_count[i*5+1]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_0'][i] = sent_count[i*5+2]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_1'][i] = sent_count[i*5+3]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sent_2'][i] = sent_count[i*5+4]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_A'][i] = emo_count[i*4]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_F'][i] = emo_count[i*4+1]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_H'][i] = emo_count[i*4+2]
# /var/folders/g3/mkltnc9s3t90y6gv9ds6trxh0000gn/T/ipykernel_7663/3634122871.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emo_S'][i] = emo_count[i*4+3]

# %%
df
# Out:
#                   count sent_-2 sent_-1 sent_0 sent_1 sent_2  emo_A  emo_F  \
# tweet_timestamp
# 2020-04-10        66987    2280   32364  11595  20050    698  15614  15927
# 2020-04-11       128897    5413   69488  20229  32620   1147  33963  34491
# 2020-04-12       111714    4441   60742  17312  27963   1256  29740  29462
# 2020-04-13       162211    5600   81173  27876  46150   1412  38172  40684
# 2020-04-14       169335    5441   84297  28808  49402   1387  39155  42427
# 2020-04-15       177313    6134   89967  30005  49675   1532  43471  43725
# 2020-04-16       183543    6041   91905  31274  52716   1607  43949  45220
#
#                  emo_H emo_S  valence_intensity  fear_intensity  \
# tweet_timestamp
# 2020-04-10       20748  3103           0.473456        0.429110
# 2020-04-11       33767  6447           0.460951        0.440764
# 2020-04-12       29219  5981           0.462061        0.439392
# 2020-04-13       47562  7917           0.469939        0.433787
# 2020-04-14       50789  8156           0.471384        0.433308
# 2020-04-15       51207  8905           0.468812        0.433064
# 2020-04-16       54323  8777           0.470868        0.432819
#
#                  anger_intensity  happiness_intensity  sadness_intensity
# tweet_timestamp
# 2020-04-10              0.425370             0.316244           0.402038
# 2020-04-11              0.435984             0.305689           0.411853
# 2020-04-12              0.435724             0.307347           0.411117
# 2020-04-13              0.427761             0.311304           0.405058
# 2020-04-14              0.426776             0.311252           0.404512
# 2020-04-15              0.429810             0.310179           0.406053
# 2020-04-16              0.428664             0.311743           0.404266
